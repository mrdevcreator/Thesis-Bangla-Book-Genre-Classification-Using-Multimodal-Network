# %%
import os
import shutil
import random

# %%
# # Set the path to the 'data' folder
# data_folder = "data"

# # Percentage of images for training and validation
# train_percentage = 0.8
# validation_percentage = 0.1

# for folder_name in ['গণিত, বিজ্ঞান ও প্রযুক্তি', 'ইতিহাস ও রাজনীতি', 'গল্প', 'কমিক্স ও ছবির গল্প']:
#     folder_path = os.path.join(data_folder, folder_name)

#     # Create 'train' and 'validation' folders inside each folder
#     train_folder = os.path.join(folder_path, 'train')
#     validation_folder = os.path.join(folder_path, 'validation')

#     os.makedirs(train_folder, exist_ok=True)
#     os.makedirs(validation_folder, exist_ok=True)

#     # Get the list of image files in the current folder
#     image_files = os.listdir(folder_path)

#     # Calculate the number of images for training and validation
#     num_images = len(image_files)
#     num_train = int(train_percentage * num_images)
#     num_validation = int(validation_percentage * num_images)

#     # Randomly shuffle the list of image files
#     random.shuffle(image_files)

#     # Copy images to 'train' folder
#     for image_file in image_files[:num_train]:
#         src_path = os.path.join(folder_path, image_file)
#         dest_path = os.path.join(train_folder, image_file)
#         shutil.copy(src_path, dest_path)

#     # Copy images to 'validation' folder
#     for image_file in image_files[num_train:num_train + num_validation]:
#         src_path = os.path.join(folder_path, image_file)
#         dest_path = os.path.join(validation_folder, image_file)
#         shutil.copy(src_path, dest_path)

# # The remaining 80% of images in each folder remain unchanged

# %%
# # Set the path to the 'data' folder
# data_folder = "data"

# # Percentage of images for training and validation
# train_percentage = 0.2
# validation_percentage = 0.4

# # Iterate through folders 0, 1, 2, and 3
# for folder_name in ['গণিত, বিজ্ঞান ও প্রযুক্তি', 'ইতিহাস ও রাজনীতি', 'গল্প', 'কমিক্স ও ছবির গল্প']:
#     folder_path = os.path.join(data_folder, folder_name)

#     # Create 'train' and 'validation' folders inside each folder
#     train_folder = os.path.join(folder_path, 'train')
#     validation_folder = os.path.join(folder_path, 'validation')

#     os.makedirs(train_folder, exist_ok=True)
#     os.makedirs(validation_folder, exist_ok=True)

#     # Get the list of image files in the current folder
#     image_files = [f for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]

#     # Calculate the number of images for training and validation
#     num_images = len(image_files)
#     num_train = int(train_percentage * num_images)
#     num_validation = int(validation_percentage * num_images)

#     # Randomly shuffle the list of image files
#     random.shuffle(image_files)

#     # Move images to 'train' folder
#     for image_file in image_files[:num_train]:
#         src_path = os.path.join(folder_path, image_file)
#         dest_path = os.path.join(train_folder, image_file)
#         shutil.move(src_path, dest_path)

#     # Move images to 'validation' folder
#     for image_file in image_files[num_train:num_train + num_validation]:
#         src_path = os.path.join(folder_path, image_file)
#         dest_path = os.path.join(validation_folder, image_file)
#         shutil.move(src_path, dest_path)

# # The remaining 80% of images in each folder remain unchanged

# %%
# import os
# import shutil
# import random

# # Set the path to the 'data' folder
# data_folder = "All_data/Defence"

# # Percentage split for Train, Test, and Validation
# train_percentage = 0.7
# test_percentage = 0.2
# validation_percentage = 0.1

# for folder_name in ['গল্প']:
#     folder_path = os.path.join(data_folder, folder_name)
#     print(folder_path)

#     # Create 'train', 'test', and 'validation' folders inside each folder
#     train_folder = os.path.join(folder_path, 'train2')
#     test_folder = os.path.join(folder_path, 'test2')
#     validation_folder = os.path.join(folder_path, 'validation2')

#     os.makedirs(train_folder, exist_ok=True)
#     os.makedirs(test_folder, exist_ok=True)
#     os.makedirs(validation_folder, exist_ok=True)

#     # Get the list of image files in the current folder
#     image_files = [file for file in os.listdir(folder_path) if file.endswith(('jpg', 'jpeg', 'png'))]

#     # Calculate the number of images for each set
#     num_images = len(image_files)
#     num_train = int(train_percentage * num_images)
#     num_test = int(test_percentage * num_images)
#     num_validation = int(validation_percentage * num_images)

#     # Randomly shuffle the list of image files
#     random.shuffle(image_files)

#     # Copy images to 'train' folder
#     for image_file in image_files[:num_train]:
#         src_path = os.path.join(folder_path, image_file)
#         dest_path = os.path.join(train_folder, image_file)
#         shutil.copy(src_path, dest_path)

#     # Copy images to 'test' folder
#     for image_file in image_files[num_train:num_train + num_test]:
#         src_path = os.path.join(folder_path, image_file)
#         dest_path = os.path.join(test_folder, image_file)
#         shutil.copy(src_path, dest_path)

#     # Copy images to 'validation' folder
#     for image_file in image_files[num_train + num_test:num_train + num_test + num_validation]:
#         src_path = os.path.join(folder_path, image_file)
#         dest_path = os.path.join(validation_folder, image_file)
#         shutil.copy(src_path, dest_path)

# print("Images have been successfully divided into Train, Test, and Validation folders.")
# Out:
# All_data/Defence/গল্প
# Images have been successfully divided into Train, Test, and Validation folders.
